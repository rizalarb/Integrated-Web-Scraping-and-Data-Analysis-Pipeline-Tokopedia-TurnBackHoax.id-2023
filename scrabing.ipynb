# %% [markdown]
# # Web Scrabing

# %% [markdown]
# ## Toped API V.0.1

# %%
import numpy
import json
import requests

# %%
url = 'https://gql.tokopedia.com/graphql/SearchProductQueryV4'


payload = [{
    "operationName":"SearchProductQueryV4", # keynya dikasi kutip
    "variables":{
        "params":"device=desktop&navsource=&ob=23&page=1&q=handphone&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start=0&topads_bucket=true&unique_id=a038bc0744311c1e3396f9e1cc19bd41&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=12210375&variants="
    },
    "query":"query SearchProductQueryV4($params: String!) {\n  ace_search_product_v4(params: $params) {\n    header {\n      totalData\n      totalDataText\n      processTime\n      responseCode\n      errorMessage\n      additionalParams\n      keywordProcess\n      componentId\n      __typename\n    }\n    data {\n      banner {\n        position\n        text\n        imageUrl\n        url\n        componentId\n        trackingOption\n        __typename\n      }\n      backendFilters\n      isQuerySafe\n      ticker {\n        text\n        query\n        typeId\n        componentId\n        trackingOption\n        __typename\n      }\n      redirection {\n        redirectUrl\n        departmentId\n        __typename\n      }\n      related {\n        position\n        trackingOption\n        relatedKeyword\n        otherRelated {\n          keyword\n          url\n          product {\n            id\n            name\n            price\n            imageUrl\n            rating\n            countReview\n            url\n            priceStr\n            wishlist\n            shop {\n              city\n              isOfficial\n              isPowerBadge\n              __typename\n            }\n            ads {\n              adsId: id\n              productClickUrl\n              productWishlistUrl\n              shopClickUrl\n              productViewUrl\n              __typename\n            }\n            badges {\n              title\n              imageUrl\n              show\n              __typename\n            }\n            ratingAverage\n            labelGroups {\n              position\n              type\n              title\n              url\n              __typename\n            }\n            componentId\n            __typename\n          }\n          componentId\n          __typename\n        }\n        __typename\n      }\n      suggestion {\n        currentKeyword\n        suggestion\n        suggestionCount\n        instead\n        insteadCount\n        query\n        text\n        componentId\n        trackingOption\n        __typename\n      }\n      products {\n        id\n        name\n        ads {\n          adsId: id\n          productClickUrl\n          productWishlistUrl\n          productViewUrl\n          __typename\n        }\n        badges {\n          title\n          imageUrl\n          show\n          __typename\n        }\n        category: departmentId\n        categoryBreadcrumb\n        categoryId\n        categoryName\n        countReview\n        customVideoURL\n        discountPercentage\n        gaKey\n        imageUrl\n        labelGroups {\n          position\n          title\n          type\n          url\n          __typename\n        }\n        originalPrice\n        price\n        priceRange\n        rating\n        ratingAverage\n        shop {\n          shopId: id\n          name\n          url\n          city\n          isOfficial\n          isPowerBadge\n          __typename\n        }\n        url\n        wishlist\n        sourceEngine: source_engine\n        __typename\n      }\n      violation {\n        headerText\n        descriptionText\n        imageURL\n        ctaURL\n        ctaApplink\n        buttonText\n        buttonType\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
}]


req = requests.post(url, json=payload).json() #membuat variable array
print(req)

# %%
rows = req[0]["data"]["ace_search_product_v4"]["data"]["products"]
print(len(rows))
# Out:
# 60

# %%
for i in range(0, len(rows)):
  no = i
  nama_produk = rows[i]['name']
  harga = rows[i]['price']
  bintang = rows[i]['ratingAverage']
  lokasi = rows[i]['shop']['city']
  toko = rows[i]['shop']['name']
  print(no,nama_produk, harga, bintang, toko, lokasi)
# Out:
# 0 Infinix Hot 12 Play 4/64 Garansi Resmi Rp1.425.000 5.0 ACS Jakarta Pusat
# 1 FS Infinix Hot 12 Play 4/64 GB - Garansi Resmi Rp1.435.000 4.9 Wahana Selular Jakarta Timur
# 2 PROMO Infinix Hot 12 Play 4/64 Garansi Resmi Rp1.427.000 5.0 jikalaku Jakarta Pusat
# 3 FS Infinix Hot 12i 4/64 GB - Garansi Resmi Rp1.392.000 5.0 Wahana Selular Jakarta Timur
# 4 Infinix Hot 12 Play 4/128GB (RAM 4GB + 3GB Extend) Garansi Resmi Rp1.619.000 5.0 duniagadgetku Jakarta Barat
# 5 Samsung Galaxy A13 6/128GB 4/128GB Garansi Resmi SEIN Rp2.350.000 4.9 Dewa Ponsel Rakyat Jakarta Pusat
# 6 FS Infinix Hot 12 Play 4/128 GB - Garansi Resmi Rp1.599.000 4.9 Wahana Selular Jakarta Timur
# 7 Realme C35 4/64 4/128 RAM 4 ROM 64 128 GB 4GB 64GB 128GB Rp2.299.000 5.0 SUPER_GADGET Jakarta Pusat
# 8 Xiaomi Redmi Note 10S 8/128GB - Garansi Resmi (FS) Rp2.699.000 5.0 jikalaku Jakarta Pusat
# 9 Samsung Galaxy A03s 4/64 GB Garansi Resmi SEIN Rp1.598.000 4.9 Gudang-HP Jakarta Pusat
# ...

# %%
#page 1
#"device=desktop&navsource=&ob=23&page=1&q=handphone&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start=0&topads_bucket=true&unique_id=a038bc0744311c1e3396f9e1cc19bd41&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=12210375&variants="

#Page 2
#"device=desktop&navsource=&ob=23&page=2&q=handphone&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start=60&topads_bucket=true&unique_id=a038bc0744311c1e3396f9e1cc19bd41&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=12210375&variants="

#Page 3
#"device=desktop&navsource=&ob=23&page=3&q=handphone&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start=120&topads_bucket=true&unique_id=a038bc0744311c1e3396f9e1cc19bd41&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=12210375&variants="

#Param All
def get_params():
  params = []
  for i in range(1, 79):
    page = i
    start = i*60
    param = "device=desktop&navsource=&ob=23&page={}&q=handphone&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start={}&topads_bucket=true&unique_id=a038bc0744311c1e3396f9e1cc19bd41&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=12210375&variants=".format(page, start)
    params.append(param)
  return params

# %%
if __name__ == '__main__':
  params = get_params()
  for i in range (0, len(params)):
    param = params[i]
    print(param)

# %% [markdown]
# ### Toped Scraping V.0.2

# %%
url = 'https://gql.tokopedia.com/graphql/SearchProductQueryV4'

def get_params():
  params = []
  #for i in range(1, 5):
  for i in range(1, 79):
    page = i
    start = i*60
    param = "device=desktop&navsource=&ob=23&page={}&q=handphone&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start={}&topads_bucket=true&unique_id=a038bc0744311c1e3396f9e1cc19bd41&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=12210375&variants=".format(page, start)
    params.append(param)
  return params

# %%
def scrape_page(param):
  payload = [{
    "operationName":"SearchProductQueryV4", # keynya dikasi kutip
    "variables":{
        "params": param
    },
    "query":"query SearchProductQueryV4($params: String!) {\n  ace_search_product_v4(params: $params) {\n    header {\n      totalData\n      totalDataText\n      processTime\n      responseCode\n      errorMessage\n      additionalParams\n      keywordProcess\n      componentId\n      __typename\n    }\n    data {\n      banner {\n        position\n        text\n        imageUrl\n        url\n        componentId\n        trackingOption\n        __typename\n      }\n      backendFilters\n      isQuerySafe\n      ticker {\n        text\n        query\n        typeId\n        componentId\n        trackingOption\n        __typename\n      }\n      redirection {\n        redirectUrl\n        departmentId\n        __typename\n      }\n      related {\n        position\n        trackingOption\n        relatedKeyword\n        otherRelated {\n          keyword\n          url\n          product {\n            id\n            name\n            price\n            imageUrl\n            rating\n            countReview\n            url\n            priceStr\n            wishlist\n            shop {\n              city\n              isOfficial\n              isPowerBadge\n              __typename\n            }\n            ads {\n              adsId: id\n              productClickUrl\n              productWishlistUrl\n              shopClickUrl\n              productViewUrl\n              __typename\n            }\n            badges {\n              title\n              imageUrl\n              show\n              __typename\n            }\n            ratingAverage\n            labelGroups {\n              position\n              type\n              title\n              url\n              __typename\n            }\n            componentId\n            __typename\n          }\n          componentId\n          __typename\n        }\n        __typename\n      }\n      suggestion {\n        currentKeyword\n        suggestion\n        suggestionCount\n        instead\n        insteadCount\n        query\n        text\n        componentId\n        trackingOption\n        __typename\n      }\n      products {\n        id\n        name\n        ads {\n          adsId: id\n          productClickUrl\n          productWishlistUrl\n          productViewUrl\n          __typename\n        }\n        badges {\n          title\n          imageUrl\n          show\n          __typename\n        }\n        category: departmentId\n        categoryBreadcrumb\n        categoryId\n        categoryName\n        countReview\n        customVideoURL\n        discountPercentage\n        gaKey\n        imageUrl\n        labelGroups {\n          position\n          title\n          type\n          url\n          __typename\n        }\n        originalPrice\n        price\n        priceRange\n        rating\n        ratingAverage\n        shop {\n          shopId: id\n          name\n          url\n          city\n          isOfficial\n          isPowerBadge\n          __typename\n        }\n        url\n        wishlist\n        sourceEngine: source_engine\n        __typename\n      }\n      violation {\n        headerText\n        descriptionText\n        imageURL\n        ctaURL\n        ctaApplink\n        buttonText\n        buttonType\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
  }]

  req = requests.post(url, json=payload).json()
  rows = req[0]["data"]["ace_search_product_v4"]["data"]["products"]
  #print(len(rows))
  scrape_rows = []
  for i in range(0, len(rows)):
    no = i
    nama_produk = rows[i]['name']
    harga = rows[i]['price']
    bintang = rows[i]['ratingAverage']
    lokasi = rows[i]['shop']['city']
    toko = rows[i]['shop']['name']

    scrape_rows.append((nama_produk, harga, bintang, toko, lokasi))
  return (scrape_rows)

# %%
if __name__ == '__main__':
  params = get_params()
  all_data = []
  for i in range (0, len(params)):
    param = params[i]
    #print(param)
    data = scrape_page(param)
    all_data.extend(data)
  print (all_data)

# %%
import pandas as pd
df = pd.DataFrame( all_data, columns = ['nama_produk', 'harga', 'bintang', 'toko', 'lokasi'])
df

# save to excel
df.to_excel('Data Scraping Handphone Tokopedia.xlsx', index=False)

# %%
df

# %% [markdown]
# # Belajar Scraping

# %%
from bs4 import BeautifulSoup
import requests

url = "https://turnbackhoax.id"
respond = requests.get(url)

html_text = BeautifulSoup(respond.text, 'lxml')
print (html_text)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="id">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <title>TurnBackHoax.ID – Persembahan dari MAFINDO :: Masyarakat Anti Fitnah Indonesia</title>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://turnbackhoax.id/feed/" rel="alternate" title="TurnBackHoax.ID » Feed" type="application/rss+xml"/>
# <link href="https://turnbackhoax.id/comments/feed/" rel="alternate" title="TurnBackHoax.ID » Umpan Komentar" type="application/rss+xml"/>
# <script type="text/javascript">
# ...

# %%
html_text = BeautifulSoup(respond.text, 'html.parser')
print (html_text)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="id">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <title>TurnBackHoax.ID – Persembahan dari MAFINDO :: Masyarakat Anti Fitnah Indonesia</title>
# <meta content="max-image-preview:large" name="robots">
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://turnbackhoax.id/feed/" rel="alternate" title="TurnBackHoax.ID » Feed" type="application/rss+xml"/>
# <link href="https://turnbackhoax.id/comments/feed/" rel="alternate" title="TurnBackHoax.ID » Umpan Komentar" type="application/rss+xml"/>
# <script type="text/javascript">
# ...

# %% [markdown]
# # TurnBackHoax

# %% [markdown]
# ## Link Pada Page 1

# %%
import requests
from bs4 import BeautifulSoup

# Membuat request ke situs web
url = "https://turnbackhoax.id"
response = requests.get(url)

# Parsing HTML response
soup = BeautifulSoup(response.text, 'html.parser')

# Mencari semua artikel berita
articles = soup.find_all('article')

for article in articles:
  # Mencari link artikel
    link = article.find('a')
    if link:
        print("link URL:", link.get("href"))

    # Mencari gambar dalam artikel
    image = article.find('img')
    if image:
        print("Image URL:", image['src'])

    # Mencari judul dalam artikel
    title = article.find('div', class_='mh-loop-content mh-clearfix')
    if title:
        print("title:", title.get_text(strip=True))

    print("---")
# Out:
# link URL: https://turnbackhoax.id/2023/07/06/salah-video-langkah-cerdik-prabowo-gabung-koalisi-perubahan-nyatakan-siap-perang-lawan-istana-demi-anies/
# Image URL: https://turnbackhoax.id/wp-content/uploads/2023/07/X-dua-king-meker-bersatu-03-1-326x245.png
# title: [SALAH] Video “LANGKAH CERDIK PRABOWO!!! GABUNG KOALISI PERUBAHAN & NYATAKAN SIAP PERANG LAWAN ISTANA DEMI ANIES”Juli 6, 2023Aribowo Sasmito0MENYESATKAN, isi video TIDAK berkaitan dengan judul dan deskripsi. FAKTA: selain berisi gambar pratinjau (thumbnail) hasil SUNTINGAN, video sebenarnya berisi pembacaan artikel dari media dan[…]
# ---
# link URL: https://turnbackhoax.id/2023/07/05/salah-video-yang-diambil-saat-konser-coldplay/
# Image URL: https://turnbackhoax.id/wp-content/uploads/2023/07/photo1688558671-326x245.jpeg
# ...

# %% [markdown]
# ## Scraping Konten Berita

# %%
content_link = "https://turnbackhoax.id/2017/12/28/hoax-ayooo-ke-musium-gajah-ada-pameran-budaya-arab/"
response = requests.get(content_link)

# Parsing HTML response
html_c = BeautifulSoup(response.text, 'html.parser')
# Mencari semua artikel berita
title =  html_c.find('h1', class_="entry-title").get_text()
tag = html_c.find ('span', class_="entry-meta-categories").get_text()
image = (html_c.find('figure', class_= 'entry-thumbnail')).find('img')
date = html_c.find('span', class_= 'entry-meta-date updated').find('a').get_text()

# Mencari elemen dengan kelas "entry-content" dan mengambil paragrafnya
entry_content = html_c.find(class_='entry-content')
paragraphs = entry_content.find_all('p')

# Merapikan paragraf
clean_paragraphs = [p.get_text().strip() for p in paragraphs if p.get_text().strip()]

# Menampilkan paragraf yang telah dirapikan
for p in clean_paragraphs:
    print(p)

print(image['src'])
print(date)
# Out:
# SUMBER: Media Sosial
# NARASI:
# Assalamuallaikum wr wb
# ada info: Ayooo ke musium gajah ada pameran budaya arab. Dapat souvenir gratis Al Qur’an dari saudia arabia….poster mesjid Nabawi dan Masjidil haram….makan berbagai kurma sepuasnya…bs bw pl diijinkan.. jgn lupa bw plastik kecil kl pk tisue yg disediakan lengket…minum kopi arab dan zam2 disediakan….sp tgl 30 Maret 2017
# Waktu Kunjungan & Tiket Masuk:
# Senin dan hari besar nasional : Tutup
# Selasa – Jum’at : 08.00 – 16.00
# Sabtu – Minggu : 08.00 – 17.00
# Tiket Masuk
# 1. Pengunjung Perorangan :
# a. Dewasa : Rp 5.000,-
# b. Anak-anak : Rp 2.000,-
# 2. Pengunjung Rombongan (minimum 20 orang)
# a. Dewasa : Rp 3.000,-
# b. Anak-anak (TK s.d. SMA) Rp 1.000,-
# PENJELASAN:
# ...

# %%
# Mencari elemen dengan kelas "entry-content" dan mengambil paragrafnya
entry_content = html_c.find(class_='entry-content')
paragraphs = entry_content.find_all('p')

# Mengambil paragraf yang mengandung informasi narasi dan penjelasan
narasi = paragraphs[6].get_text().strip()
penjelasan = paragraphs[9].get_text().strip()

# Menampilkan narasi dan penjelasan
print("Narasi:")
print(narasi)
print("\nPenjelasan:")
print(penjelasan)
# Out:
# Narasi:
# [NARASI]:Surabaya Jatim Putih TotalWarga Nahdliyin & Muhammadiyah Hadiri Kampanye Akbar Anies-Yenny
#
# Penjelasan:
# [PENJELASAN]:Beredar sebuah video dari channel youtube LIDAH RAKYAT yang menampilkan thumbnail gambar panggung dengan kerumunan warga disertai narasi yang menyatakan bahwa warga Nahdliyin dan Muhammadiyah hadiri kampanye akbar Anies-Yenny di Surabaya.

# %% [markdown]
# ## Srcaping Kontent Berita Page 1

# %%
# Membuat request ke situs web
url = "https://turnbackhoax.id"
response = requests.get(url)

# Parsing HTML response
html = BeautifulSoup(response.text, 'html.parser')

# Mencari semua artikel berita
articles = html.find_all('article')

for article in articles:
  # Mencari link artikel
    link = article.find('a')
    if link:
        content_link = link.get("href")
        response = requests.get(content_link)
      # Parsing HTML response
        html_c = BeautifulSoup(response.text, 'html.parser')
      # Mencari semua artikel berita
        title =  html_c.find('h1', class_="entry-title").get_text()
        tag = html_c.find ('span', class_="entry-meta-categories").get_text()
        image = html_c.find('img')
      # Mencari elemen dengan kelas "entry-content" dan mengambil paragrafnya
        entry_content = html_c.find(class_='entry-content')
        paragraphs = entry_content.find_all('p')

      # Merapikan paragraf
        clean_paragraphs = [p.get_text().strip() for p in paragraphs if p.get_text().strip()]
      # Menampilkan paragraf yang telah dirapikan
        for p in clean_paragraphs:
            print(p)

        print(title)
        print(tag)
        print(image)
        print('\n')


      # # Mengambil paragraf yang mengandung informasi narasi dan penjelasan
      #   narasi = paragraphs[6].get_text().strip()
      #   penjelasan = paragraphs[9].get_text().strip()

      # # Menampilkan narasi dan penjelasan
      #   print("Narasi:")
      #   print(narasi)
      #   print("\nPenjelasan:")
      #   print(penjelasan)
# Out:
# Hasil periksa fakta Evarizma Zahra.
# Konteks yang salah. Video tersebut diambil saat festival di Brazil pada Februari 2018, bukan merupakan kerumunan penonton Coldplay.
# =====
# KATEGORI: KONTEKS YANG SALAH
# =====
# Sumber: Twitterhttps://turnbackhoax.id/wp-content/uploads/2023/07/Coldplay-concert.pdf
# Arsip Video:https://video.twimg.com/ext_tw_video/1663035585962086402/pu/vid/358×640/mZcDp75ZMKb65W6w.mp4?tag=12
# =====
# Narasi:
# “Ini Coldplay concert. Jika kamu suka, saya pertanyakan kejiwaanmu”.
# =====
# Penjelasan:Akun Twitter @SINGAYEHUDA51 mengunggah video yang memperlihatkan kerumunan pria yang sedang merayakan rasa cinta mereka secara bersama-sama. Pengguna Twitter tersebut menulis klaim bahwa video itu diambil dari sisi penonton saat menonton Coldplay.
# Cuitan dan video yang diunggah pada 29 Mei tersebut telah disukai oleh 409 orang, dibagikan dan dikutip ulang hampir 500 kali, serta telah dilihat lebih dari 400,000 kali.
# ...

# %%
for halaman in range(1, 201):
    alamat_link = f"https://turnbackhoax.id/page/{halaman}/"
    print(alamat_link)

# %% [markdown]
# ## Sraping Konten Tiap Halaman

# %%
# Membuat request ke situs web
for halaman in range (1, 5):
    url = f"https://turnbackhoax.id/page/{halaman}/"
    response = requests.get(url)

    # Parsing HTML response
    html = BeautifulSoup(response.text, 'html.parser')

    # Mencari semua artikel berita
    articles = html.find_all('article')

    for article in articles:
      # Mencari link artikel
        link = article.find('a')
        if link:
            content_link = link.get("href")
            response = requests.get(content_link)
          # Parsing HTML response
            html_c = BeautifulSoup(response.text, 'html.parser')
          # Mencari semua artikel berita
            title =  html_c.find('h1', class_="entry-title").get_text()
            tag = html_c.find ('span', class_="entry-meta-categories").get_text()
            image = (html_c.find('figure', class_= 'entry-thumbnail')).find('img')
            date = html_c.find('span', class_= 'entry-meta-date updated').find('a').get_text()

          # Mencari elemen dengan kelas "entry-content" dan mengambil paragrafnya
            entry_content = html_c.find(class_='entry-content')
            paragraphs = entry_content.find_all('p')

          # Merapikan paragraf
            clean_paragraphs = [p.get_text().strip() for p in paragraphs if p.get_text().strip()]
          # Menampilkan paragraf yang telah dirapikan
            for p in clean_paragraphs:
                print(p)

            print(content_link)
            print(title)
            print(tag)
            print(date)
            print(image['src'])
            print('\n')
# Out:
# MENYESATKAN, isi video TIDAK berkaitan dengan judul dan deskripsi. FAKTA: selain berisi gambar pratinjau (thumbnail) hasil SUNTINGAN, video sebenarnya berisi pembacaan artikel dari media dan potongan-potongan video dari peristiwa yang konteksnya DIPELINTIR.
# Selengkapnya di bagian PENJELASAN dan REFERENSI.
# KATEGORI: Konten yang Dimanipulasi.
# SUMBER: Facebook, https://archive.ph/TSnVM (arsip cadangan).
# NARASI: “LANGKAH CERDIK PRABOWO!!! GABUNG KOALISI PERUBAHAN & NYATAKAN SIAP PERANG LAWAN ISTANA DEMI ANIES”
# PENJELASAN
# Berdasarkan 7 Jenis Mis- dan Disinformasi oleh First Draft News, termasuk “Konten yang Dimanipulasi: Ketika informasi atau gambar yang asli dimanipulasi untuk menipu”. [1]
# View this post on Instagram            A post shared by Aribowo Sasmito (@aribowosasmito)
# A post shared by Aribowo Sasmito (@aribowosasmito)
# ...

# %%
teks = '''Hasil periksa fakta Agnes Amungkasari.
Tidak ada informasi tentang adanya baliho Anies Baswedan yang terpajang di Masjidil Haram. Narasi dalam video menjelaskan tentang Rega, bocah asal Solo, yang mengaku senang bisa berfoto bersama Anies.
=====
[KATEGORI]: Konten yang Dimanipulasi
=====
[SUMBER]: https://archive.cob.web.id/archive/1687513657.005799/singlefile.html (YOUTUBE)
=====
[NARASI]: “Jadi pusat perhatian ! Baliho Anies terpajang di Masjidilharom, Ternyata akan menunaikan ibadah haji”
=====
[PENJELASAN]:
Kanal Youtube LINTAS OPINI mengunggah video dengan klaim baliho Anies Baswedan terpajang di Masjidil Haram. Hal ini disebut menjadi pusat perhatian para jamaah haji.
Sebelumnya diberitakan oleh Okezone, Anies Baswedan dan keluarga berangkat ke Arab Saudi pada 24 Juni 2023 untuk menunaikan ibadah haji.
Namun setelah menonton keseluruhan video, tidak ada informasi yang menerangkan bahwa terdapat baliho bergambar Anies Baswedan di Masjidil Haram pada saat ibadah haji berlangsung. Cuplikan video tersebut tidak memiliki keterkaitan dengan klaim yang disampaikan dalam video.
Selain itu, narasi yang dibacakan dalam video identik dengan artikel yang diunggah oleh Kompas, dengan judul “Senang Bisa Foto Bareng Anies Baswedan, Rega: Sudah Lama Saya Pengin Foto sama Pak Anies.”
Artikel yang diunggah pada 13 Juni 2023 tersebut menjelaskan tentang Rega, bocah 13 tahun asal Solo, Jawa Tengah, mengaku senang bisa foto bersama bakal capres dari Partai Nasdem, Anies Baswedan. Adapun kunjungan Anies ke Solo untuk menjadi penguji ujian doktoral Muhammad Fauzi, penyandang disabilitas tuli di Institut Seni Indonesia (ISI) Solo, Jawa Tengah.'''

kategori_label = "[KATEGORI]:"
penjelasan_label = "[PENJELASAN]:"

kategori_index = teks.index(kategori_label)
penjelasan_index = teks.index(penjelasan_label)

kategori_text = teks[:kategori_index].strip()
penjelasan_text = teks[penjelasan_index + len(penjelasan_label):].strip()

print (kategori_index)
print(penjelasan_index)

print(kategori_text)
print(penjelasan_text)
# Out:
# 246
# 503
# Hasil periksa fakta Agnes Amungkasari.
# Tidak ada informasi tentang adanya baliho Anies Baswedan yang terpajang di Masjidil Haram. Narasi dalam video menjelaskan tentang Rega, bocah asal Solo, yang mengaku senang bisa berfoto bersama Anies.
# =====
# Kanal Youtube LINTAS OPINI mengunggah video dengan klaim baliho Anies Baswedan terpajang di Masjidil Haram. Hal ini disebut menjadi pusat perhatian para jamaah haji.
# Sebelumnya diberitakan oleh Okezone, Anies Baswedan dan keluarga berangkat ke Arab Saudi pada 24 Juni 2023 untuk menunaikan ibadah haji.
# Namun setelah menonton keseluruhan video, tidak ada informasi yang menerangkan bahwa terdapat baliho bergambar Anies Baswedan di Masjidil Haram pada saat ibadah haji berlangsung. Cuplikan video tersebut tidak memiliki keterkaitan dengan klaim yang disampaikan dalam video.
# ...

# %%
# Membuat request ke situs web
for halaman in range (377, 510):
    url = f"https://turnbackhoax.id/page/{halaman}/"
    response = requests.get(url)

    # Parsing HTML response
    html = BeautifulSoup(response.text, 'html.parser')

    # Mencari semua artikel berita
    articles = html.find_all('article')

    for article in articles:
      # Mencari link artikel
        link = article.find('a')
        if link:
            content_link = link.get("href")
            response = requests.get(content_link)
          # Parsing HTML response
            html_c = BeautifulSoup(response.text, 'html.parser')
          # Mencari semua artikel berita
            try:
              title = html_c.find('h1', class_="entry-title").get_text()
            except AttributeError:
              title = None

            try:
              tag = html_c.find('span', class_="entry-meta-categories").get_text()
            except AttributeError:
              tag = None

            try:
              image_element = html_c.find('figure', class_='entry-thumbnail').find('img')
              image = image_element['src'] if image_element else None
            except AttributeError:
              image = None

            try:
              date = html_c.find('span', class_='entry-meta-date updated').find('a').get_text()
            except AttributeError:
              date = None

          # Mencari elemen dengan kelas "entry-content" dan mengambil paragrafnya
            entry_content = html_c.find(class_='entry-content')
            paragraphs = entry_content.find_all('p')

          # Merapikan paragraf
            clean_paragraphs = [p.get_text().strip() for p in paragraphs if p.get_text().strip()]

            print(content_link)
            print(title)
            print(tag)
            print(image_element['src'])
            print(date)
            print(clean_paragraphs)
            print('\n')

# %% [markdown]
# ## Fix codingan Scraping

# %%
import requests
from bs4 import BeautifulSoup

data = []

for halaman in range(377, 510):
    url = f"https://turnbackhoax.id/page/{halaman}/"
    response = requests.get(url)

    # Parsing HTML response
    html = BeautifulSoup(response.text, 'html.parser')

    # Mencari semua artikel berita
    articles = html.find_all('article')

    for article in articles:
        # Mencari link artikel
        link = article.find('a')
        if link:
            content_link = link.get("href")
            response = requests.get(content_link)
            # Parsing HTML response
            html_c = BeautifulSoup(response.text, 'html.parser')
            # Mencari semua artikel berita

            try:
              title = html_c.find('h1', class_="entry-title").get_text()
            except AttributeError:
              title = None

            try:
              tag = html_c.find('span', class_="entry-meta-categories").get_text()
            except AttributeError:
              tag = None

            try:
              image_element = html_c.find('figure', class_='entry-thumbnail').find('img')
              image = image_element['src'] if image_element else None
            except AttributeError:
              image = None

            try:
              date = html_c.find('span', class_='entry-meta-date updated').find('a').get_text()
            except AttributeError:
              date = None

            # Mencari elemen dengan kelas "entry-content" dan mengambil paragrafnya
            entry_content = html_c.find(class_='entry-content')
            paragraphs = entry_content.find_all('p')

            # Merapikan paragraf
            clean_paragraphs = [p.get_text().strip() for p in paragraphs if p.get_text().strip()]

            # Menyimpan data dalam bentuk dictionary
            article_data = {
                'link': content_link,
                'title': title,
                'tag': tag,
                'image': image_element['src'],
                'date': date,
                'paragraphs': clean_paragraphs
            }

            data.append(article_data)

# Menampilkan data yang telah disimpan
for article in data:
    print('Link:', article['link'])
    print('Title:', article['title'])
    print('Tag:', article['tag'])
    print('Image:', article['image'])
    print('Date:', article['date'])
    print('Paragraphs:', article['paragraphs'])
    print('\n')

# %%
import pandas as pd

# Membuat DataFrame dari data
df = pd.DataFrame(data)

# Menyimpan DataFrame ke dalam file Excel
df.to_excel('data_artikel_2018-2019.xlsx', index=False)

# %%
import pandas as pd

# Membaca file Excel ke dalam DataFrame
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/ml_storage/TA/Agustus 9_Febuari 13 2020.xlsx')

data = pd.DataFrame(df)
# Menampilkan DataFrame
data.tail()
# Out:
#                                                    link  \
# 1175  https://turnbackhoax.id/2020/02/13/salah-ribua...
# 1176  https://turnbackhoax.id/2020/02/13/salah-struk...
# 1177  https://turnbackhoax.id/2020/02/13/salah-video...
# 1178  https://turnbackhoax.id/2020/02/13/salah-dubes...
# 1179  https://turnbackhoax.id/2020/02/13/salah-surat...
#
#                                                   title  \
# 1175  [SALAH] “Ribuan Burung Gagak Muncul di Wuhan M...
# 1176  [SALAH] Struk Tol Bisa Digunakan Untuk Klaim A...
# 1177  [SALAH] Video Detik-Detik Tsunami Jepang 12 Fe...
# 1178  [SALAH] Dubes China Buka Kartu: Tiap Tahun, 2 ...
# 1179  [SALAH] Surat Pengumuman Lelang Jabatan di Kem...
#
#                                    tag  \
# 1175             Fitnah / Hasut / Hoax
# 1176  Fitnah / Hasut / Hoax, Lain-lain
# 1177             Fitnah / Hasut / Hoax
# 1178             Fitnah / Hasut / Hoax
# 1179             Fitnah / Hasut / Hoax
#
# ...

# %%
urllib.request.urlretrieve('https://turnbackhoax.id/wp-content/uploads/2020/07/Screenshot-1119-641x381.png', 'image_name.jpg')
# Out:
# ('image_name.jpg', <http.client.HTTPMessage at 0x7fc4a5ffbb50>)

# %%
import string

title = '[SALAH] Foto “Ini penampakan beberapa ORANG CHINA berseragam BRIMOB/POLISI”'

# Menghapus tanda baca dari judul artikel, kecuali tanda kutip dan tanda petik dua
exclude_punctuation = set(string.punctuation).union(set([chr(i) for i in [34, 39, 8220, 8221]]))
title_clean = ''.join(char for char in title if char not in exclude_punctuation)

print(title_clean)
# Out:
# SALAH Foto Ini penampakan beberapa ORANG CHINA berseragam BRIMOBPOLISI

# %%
chr(8216)
# Out:
# '‘'

# %%
c = [str(ord(chr))+str(chr) for chr in title]
c

# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://turnbackhoax.id/"

for year in range(2023, 2022, -1):
    for month in range(12, 0,-1):
        for page in range(30, 0,-1):
            url = f"{base_url}{year:04d}/{month:02d}/page/{page}/"

            response = requests.get(url)

            if response.status_code == 404:
                break  # Keluar dari loop jika laman tidak ditemukan


            soup = BeautifulSoup(response.content, 'html.parser')

            # Lakukan operasi yang Anda butuhkan di sini, misalnya, ekstraksi informasi dari laman
            print(f"Accessed: {url}")

# %% [markdown]
# # Scraping website Turnbackhoax dan Republika

# %% [markdown]
# ## Webscrabing website Turnbackhoax

# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://turnbackhoax.id/"
data = []

for year in range(2023, 2022, -1):
  print("^"*100)
  for month in range(12, 0, -1):
    print("&"*100)
    for day in range(30, 0, -1):
      print("*"*100)
      url = f"{base_url}{year:04d}/{month:02d}/{day:02d}/"
      # url = f"{base_url}{2023}/{3}/page/{3}/"
      print (url)


      response = requests.get(url)
      if response.status_code == 404:
        continue # lanjutkan loop jika laman tidak ditemukan

      # Parsing HTML response
      html = BeautifulSoup(response.text, 'html.parser')

      # Mencari semua artikel berita
      articles = html.find_all('article')


      for article in articles:
        print("()"*100)
        # Mencari link artikel
        link = article.find('a')
        if link:
          content_link = link.get("href")
          response = requests.get(content_link)

          # Parsing HTML response
          html_c = BeautifulSoup(response.text, 'html.parser')
                    # Mencari semua artikel berita

          # Inisialisasi variabel-variabel ke None
          title = None
          tag = None
          image = None
          date = None

          try:
            title = html_c.find('h1', class_="entry-title").get_text()
          except AttributeError:
            title = None

          try:
            tag = html_c.find('span', class_="entry-meta-categories").get_text()
          except AttributeError:
                      tag = None

          try:
            image_element = html_c.find('figure', class_='entry-thumbnail').find('img')
            image = image_element['src'] if image_element else None
          except AttributeError:
            image = None

          try:
            date = html_c.find('span', class_='entry-meta-date updated').find('a').get_text()
          except AttributeError:
            date = None

          # Mencari elemen dengan kelas "entry-content" dan mengambil paragrafnya
          entry_content = html_c.find(class_='entry-content')
          paragraphs = entry_content.find_all('p')

          # Merapikan paragraf
          clean_paragraphs = [p.get_text().strip() for p in paragraphs if p.get_text().strip()]

          # Menyimpan data dalam bentuk dictionary
          article_data = {
                        'link': content_link,
                        'title': title,
                        'tag': tag,
                        'image': image,
                        'date': date,
                        'paragraphs': clean_paragraphs
                    }
          print(content_link)
          print(title)
          print(image)
          print(tag)
          print(image_element['src'])
          print(date)
          print(clean_paragraphs)
          print('\n')
          data.append(article_data)

# Menampilkan data yang telah disimpan
# for article in data:
#     print('Link:', article['link'])
#     print('Title:', article['title'])
#     print('Tag:', article['tag'])
#     print('Image:', article['image'])
#     print('Date:', article['date'])
#     print('Paragraphs:', article['paragraphs'])
#     print('\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# Fitnah / Hasut / Hoax
# https://turnbackhoax.id/wp-content/uploads/2023/03/santri-desak-cak-nun-ditangkap.jpg
# Maret 7, 2023
# ...

# %%
import os
import urllib.request
import string

# Membuat direktori di Google Drive untuk menyimpan gambar
main_folder = '/content/drive/MyDrive/Colab Notebooks/ml_storage/TA/turnbackhoax_2023_2022'
if not os.path.exists(main_folder):
    os.makedirs(main_folder)

# Tentukan folder utama untuk menyimpan gambar dan subfolder hoax dan fakta
hoax_folder = os.path.join(main_folder, 'hoax')
if not os.path.exists(hoax_folder):
    os.makedirs(hoax_folder)
fakta_folder = os.path.join(main_folder, 'fakta')
if not os.path.exists(fakta_folder):
    os.makedirs(fakta_folder)

# Loop untuk mengunduh dan menyimpan gambar
for article, row in df.iterrows():
    image_url = row['image']
    title = row['title']

    # Menghapus tanda baca dari judul artikel, kecuali tanda kutip dan tanda petik dua
    exclude_punctuation = set(string.punctuation).union(set([chr(i) for i in [34, 39, 8216, 8217, 8220, 8221]]))
    title_clean = ''.join(char for char in title if char not in exclude_punctuation)

    # Dapatkan kata pertama dari judul artikel
    first_word = title_clean.split()[0].lower()  # Ambil kata pertama dan ubah menjadi huruf kecil

    # Tentukan subfolder tujuan berdasarkan kata pertama
    if first_word == 'hoax' or first_word == 'salah':
        folder_path = hoax_folder
    else:
        folder_path = fakta_folder

    print (first_word)
    print (folder_path)
    # Gabungkan subfolder tujuan dengan nama file gambar
    image_name = os.path.join(folder_path, f"{title_clean}_{article}.jpg")

    try:
        urllib.request.urlretrieve(image_url, image_name)
        print(f"Gambar {article} '{title_clean}' telah diunduh dan disimpan di {folder_path}.")
    except Exception as e:
        error_file_name = f"{folder_path}/{title_clean}_{article}.txt"
        with open(error_file_name, 'w') as ef:
            ef.write(f"Gagal mengunduh gambar. Error: {str(e)}")
            ef.close()

        print(f"Gagal mengunduh gambar untuk '{title_clean}_{article}'. File error telah dibuat.")
        continue
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/turnbackhoax_2023_2022/hoax
# Gambar 74 'SALAH JOKOWI RESMIKAN PASANGAN GANJAR PRANOWORIDWAN KAMIL UNTUK PILPRES 2024' telah diunduh dan disimpan di /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/turnbackhoax_2023_2022/hoax.
# salah
# /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/turnbackhoax_2023_2022/hoax
# Gambar 75 'SALAH AIRLANGGA HARTANTO NYATAKAN USUNG GANJAR CAPRES DI DEPAN MEDIA' telah diunduh dan disimpan di /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/turnbackhoax_2023_2022/hoax.
# salah
# /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/turnbackhoax_2023_2022/hoax
# Gambar 76 'SALAH SURYA PALOH BUBARKAN ACARA PERESMIAN CAWAPRES GANJAR' telah diunduh dan disimpan di /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/turnbackhoax_2023_2022/hoax.
# salah
# /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/turnbackhoax_2023_2022/hoax
# ...

# %%
import re

text = """
KATEGORI: IMPOSTER CONTENT/ KONTEN TIRUAN

===

SUMBER: TANGKAPAN LAYAR SURAT PERJANJIAN

===

NARASI:

PERJANJIAN ANGGOTA

VERIFIKAS SALDO

Kegiatan berkonsep tugas berkomisi yang diawasi oleh badan Kementerian Komunikasi dan Informatika di bawah naungan Bank Indonesia yang mentayakan bahwa anggota yang melakukan kegiatan di perusahaan  tersebut berhak mendapatkan perlindungan atas saldo yang dimiliki, maka dibuatkan surat pernyataan sesuai keterangan dan pada tanggal : 29 Desember 2022

Kami selaku Kementerian Komunikasi dan Informatika menyatakan apabila pinjaman yang dilakukan telah diselesaikan oleh anggota maka anggota berhak melakukan penarikan dan perusahaan telah sepakat menyetujui penarikannya sesuai dengan prosedur yang berlaku:

===

PENJELASAN: Beredar surat perjanjian verifikasi saldo mengatasnamakan Bank Indonesia. Surat tersebut juga mencatut salah satu pejabat BI pada bagian tanda tangan, beserta cap Bank Indonesia.

Melansir dari akun media sosial resmi Instagram Bank Indonesia, dengan tegas dinyatakan jika surat perjanjian verifikasi saldo tersebut adalah tidak benar alias hoaks. BI menyatakan jika sebagai bank sentral, pihaknya tidak melakukan kegiatan komersial seperti bank umum, termasuk menerbitkan surat verifikasi saldo seperti yang beredar.

“#SobatRupiah, ada informasi #Hoaks mengenai pengecekan atau verifikasi saldo mengatasnamakan Bank Indonesia yang patut diwaspadai.
Melalui #BIWaspadaHoaks kali ini, kami ingin menyampaikan bahwa Bank Indonesia tidak pernah mengeluarkan surat perjanjian verifikasi saldo seperti tampak pada visual.
Perlu Sobat ketahui, untuk melakukan pengecekan atau verifikasi saldo tidak dapat dilakukan melalui Bank Indonesia karena Bank Indonesia merupakan bank sentral yang tidak melakukan kegiatan komersial perbankan. Sobat dapat melakukan pengecekan dengan menghubungi Bank Umum Konvensional (BUK)/ Bank Umum Syariah (BUS) yang terkait. Selain itu, mohon juga berhati-hati karena dalam pengecekan atau  verifikasi saldo tidak dimintai komisi/dana.

Mari, #BeriMakna dengan menghubungi #BICARA131 untuk mengetahui informasi akurat terkait Bank Indonesia.” tegas Bank Indonesia pada laman Instagram.

Berdasar pada seluruh referensi, surat perjanjian verifikasi saldo oleh Bank Indonesia adalah palsu. Surat tersebut masuk ke dalam hoaks dengan kategori fabricated content atau konten palsu.

===

REFERENSI:

https://www.instagram.com/p/Cm_BafArB_v/
"""

# Gunakan regex untuk mengambil teks dalam konteks "NARASI:" dan "PENJELASAN:"
narasi_match = re.search(r"NARASI:\n(.*?)\n\nPENJELASAN:", text, re.DOTALL)
penjelasan_match = re.search(r"PENJELASAN: (.+)", text, re.DOTALL)

# Mengambil teks dari hasil pencocokan
if narasi_match and penjelasan_match:
    narasi_text = narasi_match.group(1)
    penjelasan_text = penjelasan_match.group(1)
else:
    narasi_text = "Tidak ditemukan teks narasi."
    penjelasan_text = "Tidak ditemukan teks penjelasan."

# Menggabungkan teks narasi dan penjelasan
merged_text = f"NARASI:\n{narasi_text}\n\nPENJELASAN: {penjelasan_text}"

# Output hasil teks yang diambil
print(merged_text)
# Out:
# NARASI:
#
# PERJANJIAN ANGGOTA
#
# VERIFIKAS SALDO
#
# Kegiatan berkonsep tugas berkomisi yang diawasi oleh badan Kementerian Komunikasi dan Informatika di bawah naungan Bank Indonesia yang mentayakan bahwa anggota yang melakukan kegiatan di perusahaan  tersebut berhak mendapatkan perlindungan atas saldo yang dimiliki, maka dibuatkan surat pernyataan sesuai keterangan dan pada tanggal : 29 Desember 2022
#
# Kami selaku Kementerian Komunikasi dan Informatika menyatakan apabila pinjaman yang dilakukan telah diselesaikan oleh anggota maka anggota berhak melakukan penarikan dan perusahaan telah sepakat menyetujui penarikannya sesuai dengan prosedur yang berlaku:
#
# ===
#
# PENJELASAN: Beredar surat perjanjian verifikasi saldo mengatasnamakan Bank Indonesia. Surat tersebut juga mencatut salah satu pejabat BI pada bagian tanda tangan, beserta cap Bank Indonesia.
#
# ...

# %%
df['paragraphs'][0]
# Out:
# ['Hasil periksa fakta Pekik Jalu Utomo.Tidak ditemukan informasi kredibel terkait klaim narasi yang beredar. Thumbnail yang menampilkan bangunan terbakar tersebut merupakan Kantor Inspektorat dan Kominfo Natuna dan bukan kantor pusat Partai NasDem.',
#  '=======',
#  '[KATEGORI]: Konten yang dimanipulasi',
#  '=======',
#  '[SUMBER]:\xa0https://archive.cob.web.id/archive/1696845109.922199/index.html\xa0(Youtube)',
#  '=======',
#  '[NARASI]:KANTOR PUSAT NASDEM DI BAK4R !! AKIBAT SURYA PALOH INGKAR JANJI',
#  'BREAKING NEWSKANTOR PUSAT NASDEM HANGUSEMOSI WARGA MEMUNCAK,AKIBAT SURYA PALOH INGKAR JANJI',
#  '=======',
#  '[PENJELASAN]:Beredar sebuah video dari channel youtube bernama KURSI POLITIK yang menampilkan gambar thumbnail sebuah bangunan terbakar dengan narasi yang menyatakan bahwa bangunan tersebut adalah kantor pusat Partai NasDem yang dibakar oleh warga akibat Surya Paloh ingkar janji.',
# ...

# %% [markdown]
# ### Save Dataset

# %%
import pandas as pd

# Membuat DataFrame dari data
df = pd.DataFrame(data)

# Menyimpan DataFrame ke dalam file Excel
df.to_excel('turnbackhoaks_2023_2022.xlsx', index=False)

# %%
# import pandas as pd
# df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/ml_storage/TA/Hoax 2017_2018_lemmatization.xlsx")
# df.head(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3461 entries, 0 to 6449
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   link        3461 non-null   object
#  1   title       3445 non-null   object
#  2   tag         3445 non-null   object
#  3   image       3461 non-null   object
#  4   date        3445 non-null   object
#  5   paragraphs  3461 non-null   object
# dtypes: object(6)
# memory usage: 189.3+ KB

# %% [markdown]
# ## Webscrabing website Republika

# %%
import requests
from bs4 import BeautifulSoup
import re

base_url = "https://republika.co.id/index/0/"
data = []

for year in range(2023, 2022, -1):
  print("^"*100)
  for month in range(12, 0, -1):
    print("&"*100)
    for day in range(30, 0, -1):
      print("*"*100)
      url = f"{base_url}{year:04d}/{month:02d}/{day:02d}/"
      # url = f"{base_url}{2023}/{3}/page/{3}/"
      print (url)


      response = requests.get(url)
      if response.status_code == 404:
        continue # lanjutkan loop jika laman tidak ditemukan

      # Parsing HTML response
      html = BeautifulSoup(response.text, 'html.parser')

      # Mencari semua artikel berita
      li_elements = html.find_all('li', class_='list-group-item list-border conten1')


      for article in li_elements:
        print("()"*100)
        # Mencari link artikel
        link = article.find('a')
        if link:
          content_link = link.get("href")
          response = requests.get(content_link)

          # Parsing HTML response
          html_c = BeautifulSoup(response.text, 'html.parser')
                    # Mencari semua artikel berita

          # Inisialisasi variabel-variabel ke None
          title = None
          tag = None
          image = None
          date = None

          try:
            title = html_c.find('div', class_='max-card__title').find('h1').get_text()
          except AttributeError:
            title = None

          try:
            tagar = html_c.find('div', class_='tag').find_all('a')
            for tag in tagar:
              tags = tag['title']
          except AttributeError:
                      tag = None

          try:
            image_element = html_c.find('div', class_=re.compile(".*max-card__image$")).find('img')
            image = image_element['src'] if image_element else None
          except AttributeError:
            image = None

          try:
            date = html_c.find('div', class_='date date-item__headline').get_text()
          except AttributeError:
            date = None

          # Mencari elemen dengan tag article dan mengambil paragrafnya
          try:
            # Coba mencari elemen <article>
            artikel = html_c.find('article')

            # Temukan semua elemen <p> dalam elemen <article>
            paragraphs = artikel.find_all('p')

            # Loop melalui elemen-elemen <p> dan ambil teksnya
            for paragraf in paragraphs:
                teks = paragraf.get_text()
                # Merapikan paragraf
                clean_paragraphs = [p.get_text().strip() for p in paragraphs if p.get_text().strip()]
          except AttributeError:
                clean_paragraphs = None




          # artikel = html_c.find('article')
          # print(artikel)

          # paragraphs = artikel.find_all('p')

          # # Merapikan paragraf
          # clean_paragraphs = [p.get_text().strip() for p in paragraphs if p.get_text().strip()]

          # Menyimpan data dalam bentuk dictionary
          article_data = {
                        'link': content_link,
                        'title': title,
                        'tag': tag,
                        'image': image,
                        'date': date,
                        'paragraphs': clean_paragraphs
                    }
          print(content_link)
          print(title)
          print(image)
          print(tag)
          print(image_element['src'])
          print(date)
          print(clean_paragraphs)
          print('\n')
          data.append(article_data)

# Menampilkan data yang telah disimpan
# for article in data:
#     print('Link:', article['link'])
#     print('Title:', article['title'])
#     print('Tag:', article['tag'])
#     print('Image:', article['image'])
#     print('Date:', article['date'])
#     print('Paragraphs:', article['paragraphs'])
#     print('\n')
# Out:
# Streaming output truncated to the last 5000 lines.
#       Selasa   10 Jan 2023  23:45 WIB
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Save Dataset

# %%
import pandas as pd

# Membuat DataFrame dari data
df = pd.DataFrame(data)

# Menyimpan DataFrame ke dalam file Excel
df.to_excel('republika_2023_2022.xlsx', index=False)

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/ml_storage/TA/Hoax 2017_2018_lemmatization.xlsx")
df.head(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3461 entries, 0 to 6449
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   link        3461 non-null   object
#  1   title       3445 non-null   object
#  2   tag         3445 non-null   object
#  3   image       3461 non-null   object
#  4   date        3445 non-null   object
#  5   paragraphs  3461 non-null   object
# dtypes: object(6)
# memory usage: 189.3+ KB

# %% [markdown]
# ## Combine Dataset

# %%
import pandas as pd

# Baca dua file Excel ke dalam DataFrames
file_path_republika = '/content/drive/MyDrive/Colab Notebooks/ml_storage/TA/republika_2023_2022.xlsx'
file_path_turnbackhoax = '/content/drive/MyDrive/Colab Notebooks/ml_storage/TA/turnbackhoax_2023_2022.xlsx'

df_republika = pd.read_excel(file_path_republika)
df_turnbackhoax = pd.read_excel(file_path_turnbackhoax)

# Gabungkan dua DataFrames menjadi satu
df = pd.concat([df_turnbackhoax, df_republika])

# Reset indeks
df = df.reset_index(drop=True)

# %%
df.info()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8191 entries, 0 to 8190
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   link        8191 non-null   object
#  1   title       5582 non-null   object
#  2   tag         5582 non-null   object
#  3   image       5181 non-null   object
#  4   date        5582 non-null   object
#  5   paragraphs  5601 non-null   object
# dtypes: object(6)
# memory usage: 384.1+ KB
#                                                    link  \
# 8186  https://sport.republika.co.id/berita/rnt9w8348...
# 8187  https://ihram.republika.co.id/berita/rnt7oc313...
# 8188  https://visual.republika.co.id/berita/rnt9p137...
# 8189  https://ihram.republika.co.id/berita/rnt7ka313...
# 8190  https://ekonomi.republika.co.id/berita/rnt9jv4...
#
#                                                   title  \
# 8186  Ronaldo dan Deretan Superstar yang Pindah ke K...
# ...

# %% [markdown]
# ### Clean NaN Records

# %%
df = df.dropna()

# %%
df = df.reset_index(drop=True)

# %%
# Mencari baris dengan nilai kosong di kolom 'image' dan menghapusnya
index_to_drop = df.isna()

# Menampilkan baris yang dihapus menggunakan iloc
print("\nBaris yang Dihapus:")

deleted_rows_index = index_to_drop[index_to_drop.any(axis=1)].index
print(deleted_rows_index)
# Out:
# Baris yang Dihapus:
# Int64Index([], dtype='int64')

# %% [markdown]
# ### Save Dataset

# %%
import pandas as pd

# Menyimpan DataFrame ke dalam file Excel
df.to_excel('combine_2023_2022.xlsx', index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5165 entries, 0 to 5164
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   link        5165 non-null   object
#  1   title       5165 non-null   object
#  2   tag         5165 non-null   object
#  3   image       5165 non-null   object
#  4   date        5165 non-null   object
#  5   paragraphs  5165 non-null   object
# dtypes: object(6)
# memory usage: 242.2+ KB

# %%
df['title'][1740]
# Out:
# '[SALAH] Video TikTok “Waspada Cuaca Ekstrem 29-30 Desember 2022”'

# %%
df['title'][1741]
# Out:
# "'Pecah Bintang', Ini Sederet Torehan Kolonel CHK Agus Hari Suyanto Selama Berkarier di TNI"

# %% [markdown]
# ### Donwload all Pictures

# %%
image_url = 'https://turnbackhoax.id/wp-content/uploads/2023/01/X-cuaca-ekstrem-2022-03-1-678x381.png'
image_name = 'turn.jpg'
article = 1740
title_clean = 'turnen'
folder_path = '/content/sample_data'
try:
       urllib.request.urlretrieve(image_url, image_name)
       print(f"Gambar {article} '{title_clean}' telah diunduh dan disimpan di {folder_path}.")
except Exception as e:
       error_file_name = f"{folder_path}/{title_clean}_{article}.txt"
       with open(error_file_name, 'w') as ef:
           ef.write(f"Gagal mengunduh gambar. Error: {str(e)}")
           ef.close()

       print(f"Gagal mengunduh gambar untuk '{title_clean}_{article}'. File error telah dibuat.")
# Out:
# Gambar 1740 'turnen' telah diunduh dan disimpan di /content/sample_data.

# %%
import os
import urllib.request



# Daftar link gambar
image_links = [
    "https://static.republika.co.id/uploads/images/inpicture_slide/bintang-1-representasi-pangkat-brigadir-jenderal-di-tni-ad_231011180706-135.jpg",
    "https://static.republika.co.id/uploads/images/inpicture_slide/penasehat-khusus-amerika-serikat-untuk-perwujudan-dan-penghormatan-isu_231011235710-595.jpg",
    "https://static.republika.co.id/uploads/images/inpicture_slide/009405900-1693996282-830-556.jpg",
    "https://static.republika.co.id/uploads/images/inpicture_slide/wali-kota-sukabumi-achmad-fahmi-meresmikan-mal-pelayanan-publik_211223142218-266.jpg",
    "https://static.republika.co.id/uploads/images/inpicture_slide/penggunaan-kendaraan-listrik-untuk-mengurangi-polusi-udara-dinilai-tidak_230820174131-719.jpeg",
    "https://static.republika.co.id/uploads/images/inpicture_slide/ketersediaan-sistem-teknologi-informasi-dan-komunikasi-yang-andal_231011234852-565.jpg",
    "https://static.republika.co.id/uploads/images/inpicture_slide/ilustrasi-pelecehan_220708174411-510.png",
    "https://static.republika.co.id/uploads/images/inpicture_slide/waketum-dmi-syafruddin-kambo-berbicara-via_231011215246-301.jpg"
]

# Adding User_agent information
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)


# Direktori tujuan untuk menyimpan gambar
output_directory = '/content/sample_data'

# Membuat direktori jika belum ada
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Loop untuk mengunduh gambar dan menyimpannya
for i, image_link in enumerate(image_links):
    try:
        # Mendapatkan nama file dari URL gambar
        image_name = os.path.join(output_directory, f"image_{i}.jpg")
        # Mengunduh gambar
        urllib.request.urlretrieve(image_link, image_name)
        print(f"Gambar {i} telah diunduh dan disimpan di {image_name}")
    except Exception as e:
        print(f"Gagal mengunduh gambar {i}: {str(e)}")
# Out:
# Gambar 0 telah diunduh dan disimpan di /content/sample_data/image_0.jpg
# Gambar 1 telah diunduh dan disimpan di /content/sample_data/image_1.jpg
# Gambar 2 telah diunduh dan disimpan di /content/sample_data/image_2.jpg
# Gambar 3 telah diunduh dan disimpan di /content/sample_data/image_3.jpg
# Gambar 4 telah diunduh dan disimpan di /content/sample_data/image_4.jpg
# Gambar 5 telah diunduh dan disimpan di /content/sample_data/image_5.jpg
# Gambar 6 telah diunduh dan disimpan di /content/sample_data/image_6.jpg
# Gambar 7 telah diunduh dan disimpan di /content/sample_data/image_7.jpg

# %%
import os
import urllib.request
import string

# Adding User_agent information
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

# Membuat direktori di Google Drive untuk menyimpan gambar
main_folder = '/content/drive/MyDrive/Colab Notebooks/ml_storage/TA/Coba-coba'
if not os.path.exists(main_folder):
    os.makedirs(main_folder)

# Tentukan folder utama untuk menyimpan gambar dan subfolder hoax dan fakta
hoax_folder = os.path.join(main_folder, 'hoax')
if not os.path.exists(hoax_folder):
    os.makedirs(hoax_folder)
fakta_folder = os.path.join(main_folder, 'fakta')
if not os.path.exists(fakta_folder):
    os.makedirs(fakta_folder)

# Loop untuk mengunduh dan menyimpan gambar ke 1742
start_index = 1740
# article = 1741
for article, row in df.iloc[start_index:].iterrows():
    image_url = row['image']
    print(image_url)
    print (article)
    title = row['title']

    # Menghapus tanda baca dari judul artikel, kecuali tanda kutip dan tanda petik dua
    exclude_punctuation = set(string.punctuation).union(set([chr(i) for i in [34, 39, 8216, 8217, 8220, 8221]]))
    title_clean = ''.join(char for char in title if char not in exclude_punctuation)


    # Dapatkan kata pertama dari judul artikel
    first_word = title_clean.split()[0].lower()  # Ambil kata pertama dan ubah menjadi huruf kecil

    # Tentukan subfolder tujuan berdasarkan kata pertama
    if first_word == 'hoax' or first_word == 'salah':
        folder_path = hoax_folder
    else:
        folder_path = fakta_folder

    print (first_word)
    print (folder_path)
    # Gabungkan subfolder tujuan dengan nama file gambar
    image_name = os.path.join(folder_path, f"{title_clean}_{article}.jpg")
    print(image_name)

    try:
        urllib.request.urlretrieve(image_url, image_name)
        print(f"Gambar {article} '{title_clean}' telah diunduh dan disimpan di {folder_path}.")
    except Exception as e:
        error_file_name = f"{folder_path}/{title_clean}_{article}.txt"
        with open(error_file_name, 'w') as ef:
            ef.write(f"Gagal mengunduh gambar. Error: {str(e)}")
            ef.close()

        print(f"Gagal mengunduh gambar untuk '{title_clean}_{article}'. File error telah dibuat.")
        print('\n')
        # continue
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/Coba-coba/fakta/BAT Indonesia Raih Penghargaan Top Employer 2023_4331.jpg
# Gambar 4331 'BAT Indonesia Raih Penghargaan Top Employer 2023' telah diunduh dan disimpan di /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/Coba-coba/fakta.
# https://static.republika.co.id/uploads/images/inpicture_slide/079054400-1676565112-830-556.jpg
# 4332
# lego
# /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/Coba-coba/fakta
# /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/Coba-coba/fakta/LEGO Rilis Set Mainan BTS Dijual Akhir Maret Seharga Rp 189 Juta_4332.jpg
# Gambar 4332 'LEGO Rilis Set Mainan BTS Dijual Akhir Maret Seharga Rp 189 Juta' telah diunduh dan disimpan di /content/drive/MyDrive/Colab Notebooks/ml_storage/TA/Coba-coba/fakta.
# ...
